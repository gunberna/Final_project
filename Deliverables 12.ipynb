# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set (style = 'darkgrid')

# %%
df = pd.read_csv('forecasting_case_study.csv')

# %%
sns.histplot(data= df, x='Covid_Flag', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='Covid_Flag', ylabel='Sales'>

# %%
df.plot('date', 'Sales')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import warnings
import matplotlib.pyplot as plt
y = df['Sales']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='date')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='date')
ax.set_ylabel('Sales')
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4t/3325x7j16jb8pwq0hshl_nfw0000gn/T/ipykernel_99957/388899522.py in <module>
#       4 fig, ax = plt.subplots(figsize=(20, 6))
#       5 ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='date')
# ----> 6 ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='date')
#       7 ax.set_ylabel('Sales')
#       8 ax.legend();
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    5426         offset: TimedeltaConvertibleTypes | None = None,
#    5427     ) -> Resampler:
# -> 5428         return super().resample(
#    5429             rule=rule,
#    5430             axis=axis,
#
# ...

# %%
# Split train-test set manually
train_x= [:80], train_y= [:80], test_x =[80:], test_y[80:]
# Plot train-test using matplotlib.pyplot
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('date')
plt.ylabel('Sales')
plt.plot(df, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()
# Out:
#   File "/var/folders/4t/3325x7j16jb8pwq0hshl_nfw0000gn/T/ipykernel_99957/3862905082.py", line 2
#     train_x= [:80], train_y= [:80], test_x =[80:], test_y[80:]
#               ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split
  

x= df['date']
y= df['Sales']

x_train, x_test, y_train, y_test = train_test_split(x , y ,random_state=104 , test_size=0.25, shuffle=False)
print(x_train.shape)
print(x_test.shape)

print(y_test.shape)
print(y_train.shape)

plt.plot( x_train, y_train , color = "black")
plt.plot( x_test, y_test , color = "red")
plt.ylabel('Sales')
plt.xlabel('date')
plt.xticks(rotation=45)
plt.title("Train/Test split  Data")
plt.show()
# Out:
# (913,)
# (305,)
# (305,)
# (913,)

# %%
x_train
# Out:
# 0        2/5/2017
# 1        2/5/2017
# 2        2/5/2017
# 3        2/5/2017
# 4        2/5/2017
#           ...
# 908    12/29/2019
# 909    12/29/2019
# 910    12/29/2019
# 911    12/29/2019
# 912      1/5/2020
# Name: date, Length: 913, dtype: object

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
plt.scatter(df['date'], df['Sales'])
plt.show()

# %% [markdown]
# ## Classification Model

# %%
from sklearn import tree
(x_train).array
dtc = tree.DecisionTreeClassifier(random_state=0)
dtc.fit(x_train, y_train)

dtc_eval = evaluate_model(dtc, x_test, y_test)
print('Accuracy:', dtc_eval['acc'])
print('Precision:', dtc_eval['prec'])
print('Recall:', dtc_eval['rec'])
print('F1 Score:', dtc_eval['f1'])
print('Cohens Kappa Score:', dtc_eval['kappa'])
print('Area Under Curve:', dtc_eval['auc'])
print('Confusion Matrix:\n', dtc_eval['cm'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4t/3325x7j16jb8pwq0hshl_nfw0000gn/T/ipykernel_99957/1188274440.py in <module>
#       2 (x_train).array
#       3 dtc = tree.DecisionTreeClassifier(random_state=0)
# ----> 4 dtc.fit(x_train, y_train)
#       5
#       6 dtc_eval = evaluate_model(dtc, x_test, y_test)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# ...

# %%
(x_train).array
# Out:
# <PandasArray>
# [  '2/5/2017',   '2/5/2017',   '2/5/2017',   '2/5/2017',   '2/5/2017',
#    '2/5/2017',  '2/12/2017',  '2/12/2017',  '2/12/2017',  '2/12/2017',
#  ...
#  '12/22/2019', '12/22/2019', '12/22/2019', '12/29/2019', '12/29/2019',
#  '12/29/2019', '12/29/2019', '12/29/2019', '12/29/2019',   '1/5/2020']
# Length: 913, dtype: object

# %% [markdown]
# ## Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4t/3325x7j16jb8pwq0hshl_nfw0000gn/T/ipykernel_99957/3052361555.py in <module>
#       4
#       5 model = LinearRegression()
# ----> 6 model.fit(x, y)
#       7 y_pred = model.predict(x)
#       8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %% [markdown]
# ## Boosting Algorithm

# %%
import xgboost
adaboost = AdaBoostClassifier(n_estimators = 50, learning_rate = 0.2).fit(x_train, y_train)
score = adaboost.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4t/3325x7j16jb8pwq0hshl_nfw0000gn/T/ipykernel_99957/3382991202.py in <module>
#       1 import xgboost
# ----> 2 adaboost = AdaBoostClassifier(n_estimators = 50, learning_rate = 0.2).fit(x_train, y_train)
#       3 score = adaboost.score(x_test, y_test)
#
# NameError: name 'AdaBoostClassifier' is not defined
