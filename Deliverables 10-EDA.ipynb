# %% [markdown]
# Reading the CSV file with pandas

# %%
import pandas as pd
df = pd.read_csv('forecasting_case_study.csv')
df.describe()
# Out:
#                Sales  In-Store Promo  Catalogue Promo  Store End Promo  \
# count    1218.000000     1218.000000      1218.000000      1218.000000
# mean    30294.678982        0.472085         0.212644         0.348933
# std     35032.527297        0.499425         0.409346         0.476828
# min         0.000000        0.000000         0.000000         0.000000
# 25%      7212.750000        0.000000         0.000000         0.000000
# 50%     19742.000000        0.000000         0.000000         0.000000
# 75%     40282.250000        1.000000         0.000000         1.000000
# max    288322.000000        1.000000         1.000000         1.000000
#
#        Google_Mobility   Covid_Flag        V_DAY       EASTER    CHRISTMAS
# count      1218.000000  1218.000000  1218.000000  1218.000000  1218.000000
# mean         -2.377406     0.226601     0.019704     0.019704     0.018883
# std           5.806291     0.418804     0.139040     0.139040     0.136169
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Product        date   Sales Price Discount (%)  In-Store Promo  \
# 0       SKU1    2/5/2017   27750                 0%               0
# 1       SKU1   2/12/2017   29023                 0%               1
# 2       SKU1   2/19/2017   45630                17%               0
# 3       SKU1   2/26/2017   26789                 0%               1
# 4       SKU1    3/5/2017   41999                17%               0
# ...      ...         ...     ...                ...             ...
# 1213    SKU6  10/18/2020   96619                54%               0
# 1214    SKU6  10/25/2020  115798                52%               0
# 1215    SKU6   11/1/2020  152186                54%               1
# 1216    SKU6   11/8/2020   26445                44%               1
# 1217    SKU6  11/15/2020   26414                44%               0
#
#       Catalogue Promo  Store End Promo  Google_Mobility  Covid_Flag  V_DAY  \
# ...

# %%
df.count()
# Out:
# Product               1218
# date                  1218
# Sales                 1218
# Price Discount (%)    1218
# In-Store Promo        1218
# Catalogue Promo       1218
# Store End Promo       1218
# Google_Mobility       1218
# Covid_Flag            1218
# V_DAY                 1218
# EASTER                1218
# CHRISTMAS             1218
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Product               0
# date                  0
# Sales                 0
# Price Discount (%)    0
# In-Store Promo        0
# Catalogue Promo       0
# Store End Promo       0
# Google_Mobility       0
# Covid_Flag            0
# V_DAY                 0
# EASTER                0
# CHRISTMAS             0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style= 'darkgrid')

# %%
sns.histplot(data= df, x='Catalogue Promo', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='Catalogue Promo', ylabel='Sales'>

# %%
sns.histplot(data= df, x='In-Store Promo', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='In-Store Promo', ylabel='Sales'>

# %%
sns.histplot(data= df, x='Store End Promo', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='Store End Promo', ylabel='Sales'>

# %%
sns.histplot(data= df, x='Google_Mobility', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='Google_Mobility', ylabel='Sales'>

# %%
sns.histplot(data= df, x='V_DAY', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='V_DAY', ylabel='Sales'>

# %%
sns.histplot(data= df, x='EASTER', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='EASTER', ylabel='Sales'>

# %%
sns.histplot(data= df, x='CHRISTMAS', y= 'Sales', color= 'skyblue', kde=True)
# Out:
# <AxesSubplot:xlabel='CHRISTMAS', ylabel='Sales'>

# %%
df.corr()
# Out:
#                     Sales  In-Store Promo  Catalogue Promo  Store End Promo  \
# Sales            1.000000        0.240891        -0.121081         0.235439
# In-Store Promo   0.240891        1.000000        -0.491438         0.367004
# Catalogue Promo -0.121081       -0.491438         1.000000         0.116301
# Store End Promo  0.235439        0.367004         0.116301         1.000000
# Google_Mobility  0.058781        0.056074         0.073260         0.084955
# Covid_Flag      -0.085571       -0.024732        -0.094373        -0.075321
# V_DAY           -0.008442        0.019761        -0.044805         0.020148
# EASTER          -0.010266        0.019761        -0.044805        -0.066610
# CHRISTMAS       -0.035916        0.013799         0.045834        -0.000322
#
#                  Google_Mobility  Covid_Flag     V_DAY    EASTER  CHRISTMAS
# Sales                   0.058781   -0.085571 -0.008442 -0.010266  -0.035916
# ...

# %%
df.corr().describe()
# Out:
#           Sales  In-Store Promo  Catalogue Promo  Store End Promo  \
# count  9.000000        9.000000         9.000000         9.000000
# mean   0.141537        0.133458         0.048766         0.186844
# std    0.346423        0.399791         0.398228         0.336747
# min   -0.121081       -0.491438        -0.491438        -0.075321
# 25%   -0.035916        0.013799        -0.094373        -0.000322
# 50%   -0.008442        0.019761        -0.044805         0.084955
# 75%    0.235439        0.240891         0.073260         0.235439
# max    1.000000        1.000000         1.000000         1.000000
#
#        Google_Mobility  Covid_Flag     V_DAY    EASTER  CHRISTMAS
# count         9.000000    9.000000  9.000000  9.000000   9.000000
# mean          0.054374   -0.002661  0.114783  0.084177   0.109385
# std           0.444857    0.446550  0.333780  0.345656   0.334793
# min          -0.756752   -0.756752 -0.044805 -0.108645  -0.035916
# ...

# %%
graph = sns.FacetGrid(df, col= 'Catalogue Promo', hue = 'Sales')
graph.map(plt.scatter,'Catalogue Promo', 'Store End Promo', edgecolor = 'skyblue').add_legend()
plt.show()
